# %%
import urllib.request
from urllib.request import Request
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
def askURL(url):
    head={
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36"
    }
    request=urllib.request.Request(url=url,headers=head)
    html=""
    try:
        response=urllib.request.urlopen(request)
        html=response.read().decode("utf-8")
    except urllib.error.URLError as e:
        if hasattr(e,"code"):
            print(e.code)
        if hasattr(e,"reason"):
            print(e.reason)
    return html
def getData(baseUrl):
    dataList=[]
    for i in range(10):
        url=baseUrl+str(i*25)
        html=askURL(url)
        soup=BeautifulSoup(html,"html.parser")
        #寻找评分
        findRating=re.compile(r'<br/>(.*?)</p>',re.S)
        for item in soup.find_all('div',class_='item'):
            item=str(item)
            dataList.append(re.findall(findRating, item))
    return dataList

# %%
country=getData("https://movie.douban.com/top250?start=")

# %%
country
# Out:
# [['\n                            1994\xa0/\xa0美国\xa0/\xa0犯罪 剧情\n                        '],
#  ['\n                            1993\xa0/\xa0中国大陆 中国香港\xa0/\xa0剧情 爱情 同性\n                        '],
#  ['\n                            1994\xa0/\xa0美国\xa0/\xa0剧情 爱情\n                        '],
#  ['\n                            1994\xa0/\xa0法国\xa0/\xa0剧情 动作 犯罪\n                        '],
#  ['\n                            1997\xa0/\xa0意大利\xa0/\xa0剧情 喜剧 爱情 战争\n                        '],
#  ['\n                            1997\xa0/\xa0美国\xa0/\xa0剧情 爱情 灾难\n                        '],
#  ['\n                            2001\xa0/\xa0日本\xa0/\xa0剧情 动画 奇幻\n                        '],
#  ['\n                            1993\xa0/\xa0美国\xa0/\xa0剧情 历史 战争\n                        '],
#  ['\n                            2010\xa0/\xa0美国 英国\xa0/\xa0剧情 科幻 悬疑 冒险\n                        '],
#  ['\n                            2009\xa0/\xa0美国 英国\xa0/\xa0剧情\n                        '],
# ...

# %%
b
# Out:
# ['\n                            1994\xa0/\xa0美国\xa0/\xa0犯罪 剧情\n                        ',
#  '\n                            1993\xa0/\xa0中国大陆 中国香港\xa0/\xa0剧情 爱情 同性\n                        ',
#  '\n                            1994\xa0/\xa0美国\xa0/\xa0剧情 爱情\n                        ',
#  '\n                            1994\xa0/\xa0法国\xa0/\xa0剧情 动作 犯罪\n                        ',
#  '\n                            1997\xa0/\xa0意大利\xa0/\xa0剧情 喜剧 爱情 战争\n                        ',
#  '\n                            1997\xa0/\xa0美国\xa0/\xa0剧情 爱情 灾难\n                        ',
#  '\n                            2001\xa0/\xa0日本\xa0/\xa0剧情 动画 奇幻\n                        ',
#  '\n                            1993\xa0/\xa0美国\xa0/\xa0剧情 历史 战争\n                        ',
#  '\n                            2010\xa0/\xa0美国 英国\xa0/\xa0剧情 科幻 悬疑 冒险\n                        ',
#  '\n                            2009\xa0/\xa0美国 英国\xa0/\xa0剧情\n                        ',
# ...

# %%
cou=[]
for c in b:
    c=c.replace('\n','').strip()
    d=c.split('/')
    cou.append(d[1])

# %%
cou="".join(cou)

# %%
cou
# Out:
# '\xa0美国\xa0\xa0中国大陆 中国香港\xa0\xa0美国\xa0\xa0法国\xa0\xa0意大利\xa0\xa0美国\xa0\xa0日本\xa0\xa0美国\xa0\xa0美国 英国\xa0\xa0美国 英国\xa0\xa0意大利\xa0\xa0美国\xa0\xa0印度\xa0\xa0美国\xa0\xa0法国 瑞士 德国\xa0\xa0美国 英国 加拿大 冰岛\xa0\xa0中国香港 中国大陆\xa0\xa0韩国\x
港,中国大陆,日本,中国大陆,美国,美国,中国香港,美国,美国,英国,韩国,中国大陆,日本,美国,英国,美国,法国,阿根廷,西班牙,英国,美国,中国香港,中国台湾,美国,美国,日本,美国,中国香港,英国,南非,意大利,英国,美国,日本,美国,澳大利亚,英国,美国,美国,瑞典,美国,日本,美国,英国,德国,日本,美国,美国,美国,日本,韩国,美国,法国,英国,爱尔兰,加拿大,英国,美国,英国,澳大利亚,美国,美国,中国香港,日本,美国,美国,中国大陆,中国香港,日本,美国,希腊,日本,美国,法国,泰国
# ...

# %%
coun=cou.split(',')

# %%
coun
# Out:
# ['美国',
#  '中国大陆',
#  '中国香港',
#  '美国',
#  '法国',
#  '意大利',
#  '美国',
#  '日本',
#  '美国',
#  '美国',
#  '英国',
#  '美国',
#  '英国',
#  '意大利',
#  '美国',
#  '印度',
#  '美国',
#  '法国',
#  '瑞士',
#  '德国',
#  '美国',
#  '英国',
#  '加拿大',
#  '冰岛',
#  '中国香港',
#  '中国大陆',
#  '韩国',
#  '美国',
#  '中国香港',
#  '日本',
#  '美国',
#  '美国',
#  '美国',
#  '法国',
#  '美国',
#  '英国',
#  '美国',
#  '中国大陆',
#  '中国香港',
#  '美国',
#  '美国',
#  '英国',
#  '意大利',
#  '中国大陆',
#  '法国',
#  '印度',
#  '美国',
#  '新西兰',
#  '黎巴嫩',
#  '法国',
#  '美国',
#  '美国',
#  '中国台湾',
#  '英国',
#  '加拿大',
#  '美国',
#  '美国',
#  '中国大陆',
#  '日本',
#  '中国香港',
#  '中国大陆',
#  '日本',
#  '韩国',
#  '意大利',
#  '法国',
#  '美国',
#  '美国',
#  '韩国',
#  '美国',
#  '英国',
#  '美国',
#  '德国',
#  '中国大陆',
#  '美国',
#  '美国',
#  '美国',
#  '新西兰',
#  '美国',
#  '德国',
#  '中国大陆',
#  '新西兰',
#  '美国',
#  '英国',
#  '美国',
#  '中国台湾',
#  '美国',
#  '美国',
#  '加拿大',
#  '美国',
#  '美国',
#  '澳大利亚',
#  '法国',
#  '德国',
#  '英国',
#  '波兰',
#  '美国',
#  '英国',
#  '德国',
#  '美国',
#  '西班牙',
#  '中国大陆',
#  '中国香港',
#  '意大利',
#  '美国',
#  '伊朗',
# ...

# %%
import pandas as pd

# %%
result=pd.value_counts(coun)

# %%
result
# Out:
# 美国      140
# 英国       35
# 日本       33
# 中国香港     28
# 法国       20
# 中国大陆     20
# 德国       19
# 韩国       11
# 意大利       9
# 中国台湾      8
# 加拿大       7
# 澳大利亚      7
# 印度        4
# 新西兰       3
# 瑞士        3
# 西班牙       3
# 南非        2
# 瑞典        2
# 伊朗        2
# 巴西        2
# 泰国        1
# 奥地利       1
# 黎巴嫩       1
# 冰岛        1
# 荷兰        1
# 俄罗斯       1
# 阿根廷       1
# 捷克        1
# 波兰        1
# 丹麦        1
# 爱尔兰       1
# 希腊        1
# dtype: int64

# %%
len(coun)
# Out:
# 370

# %%
type(result)
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['font.sans-serif'] = ['SimHei'] # 用来正常显示中文标签
plt.figure(dpi=300)
result.plot(kind='bar')
plt.savefig('d:/豆瓣top250不同国家排序')

# %%
a=[1,2,3]

# %%
a.pop()
# Out:
# 3

# %%
a
# Out:
# [1, 2]

# %%
a.pop(0)
# Out:
# 1

# %%
a
# Out:
# [2]
